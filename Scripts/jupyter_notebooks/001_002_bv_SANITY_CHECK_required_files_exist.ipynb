# %%
import os
import pandas as pd

# %%
preterms = pd.read_csv('../../DerivedData/preterm_group_list.csv', header=None)
controls =  pd.read_csv('../../DerivedData/control_group_list.csv', header=None)

# %%
### anat

files = {
    
   't2w' : '_desc-restore_T2w.nii.gz',
   't1w' : '_desc-restore_T1w.nii.gz',
   'ribbon' : '_desc-ribbon_dseg.nii.gz',
    'drawem' : '_desc-drawem87_dseg.nii.gz', 
    'Lwm' : '_hemi-left_wm.surf.gii',
    'Rwm' : '_hemi-right_wm.surf.gii',
    'Lsulc' : '_hemi-left_sulc.shape.gii' , 
    'Rsulc' : '_hemi-right_sulc.shape.gii' ,
    'Lcurv' : '_hemi-left_curv.shape.gii',
    'Rcurv' : '_hemi-right_curv.shape.gii'
    }

files_DMRI = {
    
    'dmri' : '_desc-preproc_dwi.nii.gz',
    'bvecs' : '_desc-preproc_dwi.bvec',
    'bvals' : '_desc-preproc_dwi.bval'
      
}


modality = 'dmri' # 'anat'

for i, row in controls.iterrows():
    if modality == 'anat':
        iDir = '/neurospin/grip/external_databases/dHCP_CR_JD_2018/release3/dhcp_anat_pipeline/sub-{}/ses-{}/anat'.format(row[0], row[1])
        iFile = 'sub-{}_ses-{}{}'.format(row[0], row[1], files['t2w'])
    
    elif modality == 'dmri':
        iDir = '/neurospin/grip/external_databases/dHCP_CR_JD_2018/release3/dhcp_dmri_shard_pipeline/sub-{}/ses-{}/dwi'.format(row[0], row[1])
        iFile = 'sub-{}_ses-{}{}'.format(row[0], row[1], files_DMRI['bvals'])
        
    if os.path.isfile(os.path.join(iDir, iFile)):
            print('YES')
    else:
            print('MISSING')
# Out:
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES

# %%
for i, row in controls.iterrows():
    
    metric = 'mean_fintra'
    iDir = '/neurospin/grip/external_databases/dHCP_CR_JD_2018/release3/dhcp_dmri_shard_pipeline/sub-{}/ses-{}/dwi/NODDI'.format(
                    row[0], row[1])
    #iFile = 'sub-{}_ses-{}_{}.nii.gz'.format(row[0], row[1], metric)
    iFile='{}.nii.gz'.format(metric)
    if os.path.isfile(os.path.join(iDir, iFile)):
            print('YES')
    else:
            print('MISSING')
# Out:
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES

# %%
for i, row in preterms.iterrows():
    
    #metric = 'mean_fintra'
    iDir = '/neurospin/grip/external_databases/dHCP_CR_JD_2018/release3/dhcp_dmri_shard_pipeline/sub-{}/ses-{}/dwi/probtrakX_results/ROIbyROI-2x2_ParacentralRshMask-ThalfusRshMask_sh/'.format(
                    row[0], row[1])
    #iFile = 'sub-{}_ses-{}_{}.nii.gz'.format(row[0], row[1], metric)
    #iFile='{}.nii.gz'.format(metric)
    iFile='fdt_paths.nii.gz'
    if os.path.isfile(os.path.join(iDir, iFile)):
            print('YES')
    else:
            print('MISSING')
# Out:
# YES
# YES
# YES
# MISSING
# YES
# YES
# MISSING
# YES
# YES
# YES
# YES
# YES
# MISSING
# YES
# YES
# MISSING
# MISSING
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# MISSING
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# YES
# MISSING
# YES
# YES
# MISSING
# YES
# YES
# MISSING
# YES
# YES
# YES
# YES
# YES
# YES
# MISSING
# YES
# YES
# YES
# YES
# YES
# YES
# YES
